# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # This mounts your Google Drive to the Colab VM.
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#       5 # TODO: Enter the foldername in your Drive where you have saved the unzipped
#       6 # assignment folder, e.g. 'cs231n/assignments/assignment1/'
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)
# Print the shape of X_train_feats to see feature dimensions
print('X_train_feats shape:', X_train_feats.shape)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])

print('X_train_feats shape:', X_train_feats.shape)
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images
# X_train_feats shape: (49000, 154)
# X_train_feats shape: (49000, 155)

# %%
# Original RGB image (0-255)
im = np.array([[[255, 0, 0],    # Red pixel
               [0, 255, 0],     # Green pixel
               [0, 0, 255]]])   # Blue pixel

# Step 1: Normalize (0-1)
normalized = im / 255
# [[[ 1., 0., 0.],  # Red
#   [ 0., 1., 0.],  # Green
#   [ 0., 0., 1.]]] # Blue
print(normalized)
# Step 2: Convert to HSV
hsv = matplotlib.colors.rgb_to_hsv(normalized)
# H: 0 for red, 0.33 for green, 0.67 for blue
# S: 1 for pure colors
# V: 1 for full brightness

# Step 3: Scale back to 0-255
# hsv = hsv * 255
hsv
# Out:
# [[[1. 0. 0.]
#   [0. 1. 0.]
#   [0. 0. 1.]]]
# array([[[0.        , 1.        , 1.        ],
#         [0.33333333, 1.        , 1.        ],
#         [0.66666667, 1.        , 1.        ]]])

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = np.arange(3e-8,5e-7,2e-8)
regularization_strengths = np.arange(1e4,2e5,2e4)

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
for lr in learning_rates:
  for reg in regularization_strengths:
    model=LinearSVM()
    model.train(X_train_feats,y_train,learning_rate=lr,reg=reg,num_iters=1500)
    val_predict=model.predict(X_val_feats)
    train_predict=model.predict(X_train_feats)
    acc_val=np.sum(val_predict==y_val)/X_val_feats.shape[0]
    acc_train=np.sum(train_predict==y_train)/X_val_feats.shape[0]
    results[(lr, reg)]=(acc_train,acc_val)
    # print(acc_val)
    if(acc_val>best_val):
      best_val=acc_val
      best_svm=model
pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 3.000000e-08 reg 1.000000e+04 train accuracy: 5.583000 val accuracy: 0.114000
# lr 3.000000e-08 reg 3.000000e+04 train accuracy: 6.433000 val accuracy: 0.137000
# lr 3.000000e-08 reg 5.000000e+04 train accuracy: 10.022000 val accuracy: 0.202000
# lr 3.000000e-08 reg 7.000000e+04 train accuracy: 17.513000 val accuracy: 0.351000
# lr 3.000000e-08 reg 9.000000e+04 train accuracy: 20.145000 val accuracy: 0.405000
# lr 3.000000e-08 reg 1.100000e+05 train accuracy: 20.220000 val accuracy: 0.417000
# lr 3.000000e-08 reg 1.300000e+05 train accuracy: 20.306000 val accuracy: 0.413000
# lr 3.000000e-08 reg 1.500000e+05 train accuracy: 20.332000 val accuracy: 0.415000
# lr 3.000000e-08 reg 1.700000e+05 train accuracy: 20.399000 val accuracy: 0.424000
# lr 3.000000e-08 reg 1.900000e+05 train accuracy: 20.393000 val accuracy: 0.418000
# lr 5.000000e-08 reg 1.000000e+04 train accuracy: 4.855000 val accuracy: 0.111000
# lr 5.000000e-08 reg 3.000000e+04 train accuracy: 11.045000 val accuracy: 0.202000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 20.102000 val accuracy: 0.426000
# lr 5.000000e-08 reg 7.000000e+04 train accuracy: 20.271000 val accuracy: 0.415000
# lr 5.000000e-08 reg 9.000000e+04 train accuracy: 20.384000 val accuracy: 0.422000
# lr 5.000000e-08 reg 1.100000e+05 train accuracy: 20.285000 val accuracy: 0.427000
# lr 5.000000e-08 reg 1.300000e+05 train accuracy: 20.307000 val accuracy: 0.421000
# lr 5.000000e-08 reg 1.500000e+05 train accuracy: 20.320000 val accuracy: 0.420000
# lr 5.000000e-08 reg 1.700000e+05 train accuracy: 20.256000 val accuracy: 0.415000
# lr 5.000000e-08 reg 1.900000e+05 train accuracy: 20.430000 val accuracy: 0.420000
# lr 7.000000e-08 reg 1.000000e+04 train accuracy: 6.140000 val accuracy: 0.112000
# lr 7.000000e-08 reg 3.000000e+04 train accuracy: 19.346000 val accuracy: 0.401000
# lr 7.000000e-08 reg 5.000000e+04 train accuracy: 20.271000 val accuracy: 0.417000
# lr 7.000000e-08 reg 7.000000e+04 train accuracy: 20.243000 val accuracy: 0.422000
# lr 7.000000e-08 reg 9.000000e+04 train accuracy: 20.244000 val accuracy: 0.404000
# lr 7.000000e-08 reg 1.100000e+05 train accuracy: 20.286000 val accuracy: 0.430000
# lr 7.000000e-08 reg 1.300000e+05 train accuracy: 20.387000 val accuracy: 0.424000
# lr 7.000000e-08 reg 1.500000e+05 train accuracy: 20.337000 val accuracy: 0.419000
# lr 7.000000e-08 reg 1.700000e+05 train accuracy: 20.404000 val accuracy: 0.424000
# lr 7.000000e-08 reg 1.900000e+05 train accuracy: 20.175000 val accuracy: 0.412000
# lr 9.000000e-08 reg 1.000000e+04 train accuracy: 7.910000 val accuracy: 0.158000
# lr 9.000000e-08 reg 3.000000e+04 train accuracy: 20.444000 val accuracy: 0.424000
# lr 9.000000e-08 reg 5.000000e+04 train accuracy: 20.380000 val accuracy: 0.421000
# lr 9.000000e-08 reg 7.000000e+04 train accuracy: 20.230000 val accuracy: 0.421000
# lr 9.000000e-08 reg 9.000000e+04 train accuracy: 20.295000 val accuracy: 0.417000
# lr 9.000000e-08 reg 1.100000e+05 train accuracy: 20.477000 val accuracy: 0.416000
# lr 9.000000e-08 reg 1.300000e+05 train accuracy: 20.211000 val accuracy: 0.433000
# lr 9.000000e-08 reg 1.500000e+05 train accuracy: 20.189000 val accuracy: 0.407000
# lr 9.000000e-08 reg 1.700000e+05 train accuracy: 20.361000 val accuracy: 0.408000
# lr 9.000000e-08 reg 1.900000e+05 train accuracy: 20.174000 val accuracy: 0.400000
# lr 1.100000e-07 reg 1.000000e+04 train accuracy: 12.132000 val accuracy: 0.236000
# lr 1.100000e-07 reg 3.000000e+04 train accuracy: 20.459000 val accuracy: 0.416000
# lr 1.100000e-07 reg 5.000000e+04 train accuracy: 20.271000 val accuracy: 0.409000
# lr 1.100000e-07 reg 7.000000e+04 train accuracy: 20.447000 val accuracy: 0.421000
# lr 1.100000e-07 reg 9.000000e+04 train accuracy: 20.026000 val accuracy: 0.404000
# lr 1.100000e-07 reg 1.100000e+05 train accuracy: 20.050000 val accuracy: 0.411000
# lr 1.100000e-07 reg 1.300000e+05 train accuracy: 20.490000 val accuracy: 0.427000
# lr 1.100000e-07 reg 1.500000e+05 train accuracy: 20.285000 val accuracy: 0.418000
# lr 1.100000e-07 reg 1.700000e+05 train accuracy: 20.130000 val accuracy: 0.414000
# lr 1.100000e-07 reg 1.900000e+05 train accuracy: 20.218000 val accuracy: 0.418000
# lr 1.300000e-07 reg 1.000000e+04 train accuracy: 14.803000 val accuracy: 0.307000
# lr 1.300000e-07 reg 3.000000e+04 train accuracy: 20.310000 val accuracy: 0.416000
# lr 1.300000e-07 reg 5.000000e+04 train accuracy: 20.241000 val accuracy: 0.410000
# lr 1.300000e-07 reg 7.000000e+04 train accuracy: 20.000000 val accuracy: 0.398000
# lr 1.300000e-07 reg 9.000000e+04 train accuracy: 20.292000 val accuracy: 0.412000
# lr 1.300000e-07 reg 1.100000e+05 train accuracy: 20.182000 val accuracy: 0.413000
# lr 1.300000e-07 reg 1.300000e+05 train accuracy: 19.801000 val accuracy: 0.393000
# lr 1.300000e-07 reg 1.500000e+05 train accuracy: 20.146000 val accuracy: 0.405000
# lr 1.300000e-07 reg 1.700000e+05 train accuracy: 20.458000 val accuracy: 0.423000
# lr 1.300000e-07 reg 1.900000e+05 train accuracy: 20.275000 val accuracy: 0.415000
# lr 1.500000e-07 reg 1.000000e+04 train accuracy: 18.389000 val accuracy: 0.370000
# lr 1.500000e-07 reg 3.000000e+04 train accuracy: 20.384000 val accuracy: 0.416000
# lr 1.500000e-07 reg 5.000000e+04 train accuracy: 20.351000 val accuracy: 0.429000
# lr 1.500000e-07 reg 7.000000e+04 train accuracy: 20.280000 val accuracy: 0.411000
# lr 1.500000e-07 reg 9.000000e+04 train accuracy: 20.384000 val accuracy: 0.404000
# lr 1.500000e-07 reg 1.100000e+05 train accuracy: 19.917000 val accuracy: 0.388000
# lr 1.500000e-07 reg 1.300000e+05 train accuracy: 19.946000 val accuracy: 0.399000
# lr 1.500000e-07 reg 1.500000e+05 train accuracy: 20.171000 val accuracy: 0.410000
# lr 1.500000e-07 reg 1.700000e+05 train accuracy: 20.203000 val accuracy: 0.416000
# lr 1.500000e-07 reg 1.900000e+05 train accuracy: 19.960000 val accuracy: 0.405000
# lr 1.700000e-07 reg 1.000000e+04 train accuracy: 19.493000 val accuracy: 0.390000
# lr 1.700000e-07 reg 3.000000e+04 train accuracy: 20.358000 val accuracy: 0.423000
# lr 1.700000e-07 reg 5.000000e+04 train accuracy: 20.451000 val accuracy: 0.432000
# lr 1.700000e-07 reg 7.000000e+04 train accuracy: 20.282000 val accuracy: 0.409000
# lr 1.700000e-07 reg 9.000000e+04 train accuracy: 20.292000 val accuracy: 0.399000
# lr 1.700000e-07 reg 1.100000e+05 train accuracy: 20.291000 val accuracy: 0.430000
# lr 1.700000e-07 reg 1.300000e+05 train accuracy: 20.406000 val accuracy: 0.425000
# lr 1.700000e-07 reg 1.500000e+05 train accuracy: 20.090000 val accuracy: 0.410000
# lr 1.700000e-07 reg 1.700000e+05 train accuracy: 20.158000 val accuracy: 0.413000
# lr 1.700000e-07 reg 1.900000e+05 train accuracy: 20.236000 val accuracy: 0.424000
# lr 1.900000e-07 reg 1.000000e+04 train accuracy: 20.099000 val accuracy: 0.397000
# lr 1.900000e-07 reg 3.000000e+04 train accuracy: 20.263000 val accuracy: 0.421000
# lr 1.900000e-07 reg 5.000000e+04 train accuracy: 20.240000 val accuracy: 0.403000
# lr 1.900000e-07 reg 7.000000e+04 train accuracy: 20.289000 val accuracy: 0.412000
# lr 1.900000e-07 reg 9.000000e+04 train accuracy: 20.405000 val accuracy: 0.427000
# lr 1.900000e-07 reg 1.100000e+05 train accuracy: 20.010000 val accuracy: 0.415000
# lr 1.900000e-07 reg 1.300000e+05 train accuracy: 19.761000 val accuracy: 0.395000
# lr 1.900000e-07 reg 1.500000e+05 train accuracy: 19.775000 val accuracy: 0.394000
# lr 1.900000e-07 reg 1.700000e+05 train accuracy: 19.947000 val accuracy: 0.401000
# lr 1.900000e-07 reg 1.900000e+05 train accuracy: 19.885000 val accuracy: 0.406000
# lr 2.100000e-07 reg 1.000000e+04 train accuracy: 20.221000 val accuracy: 0.417000
# lr 2.100000e-07 reg 3.000000e+04 train accuracy: 20.388000 val accuracy: 0.413000
# lr 2.100000e-07 reg 5.000000e+04 train accuracy: 20.209000 val accuracy: 0.421000
# lr 2.100000e-07 reg 7.000000e+04 train accuracy: 20.313000 val accuracy: 0.415000
# lr 2.100000e-07 reg 9.000000e+04 train accuracy: 20.310000 val accuracy: 0.423000
# lr 2.100000e-07 reg 1.100000e+05 train accuracy: 20.270000 val accuracy: 0.414000
# lr 2.100000e-07 reg 1.300000e+05 train accuracy: 20.146000 val accuracy: 0.403000
# lr 2.100000e-07 reg 1.500000e+05 train accuracy: 20.024000 val accuracy: 0.398000
# lr 2.100000e-07 reg 1.700000e+05 train accuracy: 20.022000 val accuracy: 0.407000
# lr 2.100000e-07 reg 1.900000e+05 train accuracy: 20.099000 val accuracy: 0.418000
# lr 2.300000e-07 reg 1.000000e+04 train accuracy: 20.293000 val accuracy: 0.415000
# lr 2.300000e-07 reg 3.000000e+04 train accuracy: 20.387000 val accuracy: 0.413000
# lr 2.300000e-07 reg 5.000000e+04 train accuracy: 20.398000 val accuracy: 0.429000
# lr 2.300000e-07 reg 7.000000e+04 train accuracy: 20.268000 val accuracy: 0.414000
# lr 2.300000e-07 reg 9.000000e+04 train accuracy: 20.096000 val accuracy: 0.397000
# lr 2.300000e-07 reg 1.100000e+05 train accuracy: 20.205000 val accuracy: 0.416000
# lr 2.300000e-07 reg 1.300000e+05 train accuracy: 19.978000 val accuracy: 0.400000
# lr 2.300000e-07 reg 1.500000e+05 train accuracy: 20.018000 val accuracy: 0.401000
# lr 2.300000e-07 reg 1.700000e+05 train accuracy: 20.242000 val accuracy: 0.410000
# lr 2.300000e-07 reg 1.900000e+05 train accuracy: 20.010000 val accuracy: 0.405000
# lr 2.500000e-07 reg 1.000000e+04 train accuracy: 20.334000 val accuracy: 0.419000
# lr 2.500000e-07 reg 3.000000e+04 train accuracy: 20.290000 val accuracy: 0.422000
# lr 2.500000e-07 reg 5.000000e+04 train accuracy: 20.219000 val accuracy: 0.409000
# lr 2.500000e-07 reg 7.000000e+04 train accuracy: 20.001000 val accuracy: 0.398000
# lr 2.500000e-07 reg 9.000000e+04 train accuracy: 19.946000 val accuracy: 0.418000
# lr 2.500000e-07 reg 1.100000e+05 train accuracy: 20.100000 val accuracy: 0.420000
# lr 2.500000e-07 reg 1.300000e+05 train accuracy: 19.521000 val accuracy: 0.394000
# lr 2.500000e-07 reg 1.500000e+05 train accuracy: 20.006000 val accuracy: 0.413000
# lr 2.500000e-07 reg 1.700000e+05 train accuracy: 19.939000 val accuracy: 0.409000
# lr 2.500000e-07 reg 1.900000e+05 train accuracy: 20.347000 val accuracy: 0.416000
# lr 2.700000e-07 reg 1.000000e+04 train accuracy: 20.357000 val accuracy: 0.409000
# lr 2.700000e-07 reg 3.000000e+04 train accuracy: 20.250000 val accuracy: 0.421000
# lr 2.700000e-07 reg 5.000000e+04 train accuracy: 20.364000 val accuracy: 0.420000
# lr 2.700000e-07 reg 7.000000e+04 train accuracy: 20.014000 val accuracy: 0.417000
# lr 2.700000e-07 reg 9.000000e+04 train accuracy: 20.153000 val accuracy: 0.408000
# lr 2.700000e-07 reg 1.100000e+05 train accuracy: 20.261000 val accuracy: 0.420000
# lr 2.700000e-07 reg 1.300000e+05 train accuracy: 20.157000 val accuracy: 0.398000
# lr 2.700000e-07 reg 1.500000e+05 train accuracy: 20.091000 val accuracy: 0.411000
# lr 2.700000e-07 reg 1.700000e+05 train accuracy: 20.249000 val accuracy: 0.411000
# lr 2.700000e-07 reg 1.900000e+05 train accuracy: 20.173000 val accuracy: 0.409000
# lr 2.900000e-07 reg 1.000000e+04 train accuracy: 20.326000 val accuracy: 0.416000
# lr 2.900000e-07 reg 3.000000e+04 train accuracy: 20.335000 val accuracy: 0.408000
# lr 2.900000e-07 reg 5.000000e+04 train accuracy: 20.423000 val accuracy: 0.408000
# lr 2.900000e-07 reg 7.000000e+04 train accuracy: 20.164000 val accuracy: 0.425000
# lr 2.900000e-07 reg 9.000000e+04 train accuracy: 20.446000 val accuracy: 0.414000
# lr 2.900000e-07 reg 1.100000e+05 train accuracy: 20.049000 val accuracy: 0.425000
# lr 2.900000e-07 reg 1.300000e+05 train accuracy: 19.780000 val accuracy: 0.403000
# lr 2.900000e-07 reg 1.500000e+05 train accuracy: 19.894000 val accuracy: 0.414000
# lr 2.900000e-07 reg 1.700000e+05 train accuracy: 19.798000 val accuracy: 0.421000
# lr 2.900000e-07 reg 1.900000e+05 train accuracy: 19.870000 val accuracy: 0.395000
# lr 3.100000e-07 reg 1.000000e+04 train accuracy: 20.179000 val accuracy: 0.416000
# lr 3.100000e-07 reg 3.000000e+04 train accuracy: 20.357000 val accuracy: 0.407000
# lr 3.100000e-07 reg 5.000000e+04 train accuracy: 20.181000 val accuracy: 0.408000
# lr 3.100000e-07 reg 7.000000e+04 train accuracy: 20.125000 val accuracy: 0.414000
# lr 3.100000e-07 reg 9.000000e+04 train accuracy: 20.102000 val accuracy: 0.403000
# lr 3.100000e-07 reg 1.100000e+05 train accuracy: 20.024000 val accuracy: 0.422000
# lr 3.100000e-07 reg 1.300000e+05 train accuracy: 20.072000 val accuracy: 0.414000
# lr 3.100000e-07 reg 1.500000e+05 train accuracy: 19.927000 val accuracy: 0.414000
# lr 3.100000e-07 reg 1.700000e+05 train accuracy: 20.258000 val accuracy: 0.408000
# lr 3.100000e-07 reg 1.900000e+05 train accuracy: 19.892000 val accuracy: 0.395000
# lr 3.300000e-07 reg 1.000000e+04 train accuracy: 20.264000 val accuracy: 0.419000
# lr 3.300000e-07 reg 3.000000e+04 train accuracy: 20.234000 val accuracy: 0.412000
# lr 3.300000e-07 reg 5.000000e+04 train accuracy: 20.253000 val accuracy: 0.426000
# lr 3.300000e-07 reg 7.000000e+04 train accuracy: 20.238000 val accuracy: 0.411000
# lr 3.300000e-07 reg 9.000000e+04 train accuracy: 19.864000 val accuracy: 0.395000
# lr 3.300000e-07 reg 1.100000e+05 train accuracy: 19.823000 val accuracy: 0.422000
# lr 3.300000e-07 reg 1.300000e+05 train accuracy: 19.659000 val accuracy: 0.400000
# lr 3.300000e-07 reg 1.500000e+05 train accuracy: 20.507000 val accuracy: 0.430000
# lr 3.300000e-07 reg 1.700000e+05 train accuracy: 20.170000 val accuracy: 0.425000
# lr 3.300000e-07 reg 1.900000e+05 train accuracy: 19.968000 val accuracy: 0.399000
# lr 3.500000e-07 reg 1.000000e+04 train accuracy: 20.399000 val accuracy: 0.418000
# lr 3.500000e-07 reg 3.000000e+04 train accuracy: 20.264000 val accuracy: 0.416000
# lr 3.500000e-07 reg 5.000000e+04 train accuracy: 20.400000 val accuracy: 0.413000
# lr 3.500000e-07 reg 7.000000e+04 train accuracy: 20.301000 val accuracy: 0.415000
# lr 3.500000e-07 reg 9.000000e+04 train accuracy: 20.326000 val accuracy: 0.418000
# lr 3.500000e-07 reg 1.100000e+05 train accuracy: 19.929000 val accuracy: 0.400000
# lr 3.500000e-07 reg 1.300000e+05 train accuracy: 20.230000 val accuracy: 0.431000
# lr 3.500000e-07 reg 1.500000e+05 train accuracy: 20.003000 val accuracy: 0.413000
# lr 3.500000e-07 reg 1.700000e+05 train accuracy: 19.857000 val accuracy: 0.415000
# lr 3.500000e-07 reg 1.900000e+05 train accuracy: 19.885000 val accuracy: 0.402000
# lr 3.700000e-07 reg 1.000000e+04 train accuracy: 20.356000 val accuracy: 0.414000
# lr 3.700000e-07 reg 3.000000e+04 train accuracy: 20.238000 val accuracy: 0.411000
# lr 3.700000e-07 reg 5.000000e+04 train accuracy: 20.257000 val accuracy: 0.418000
# lr 3.700000e-07 reg 7.000000e+04 train accuracy: 20.362000 val accuracy: 0.411000
# lr 3.700000e-07 reg 9.000000e+04 train accuracy: 20.101000 val accuracy: 0.419000
# lr 3.700000e-07 reg 1.100000e+05 train accuracy: 20.017000 val accuracy: 0.406000
# lr 3.700000e-07 reg 1.300000e+05 train accuracy: 19.807000 val accuracy: 0.400000
# lr 3.700000e-07 reg 1.500000e+05 train accuracy: 20.120000 val accuracy: 0.411000
# lr 3.700000e-07 reg 1.700000e+05 train accuracy: 19.309000 val accuracy: 0.383000
# lr 3.700000e-07 reg 1.900000e+05 train accuracy: 19.776000 val accuracy: 0.388000
# lr 3.900000e-07 reg 1.000000e+04 train accuracy: 20.248000 val accuracy: 0.413000
# lr 3.900000e-07 reg 3.000000e+04 train accuracy: 20.208000 val accuracy: 0.415000
# lr 3.900000e-07 reg 5.000000e+04 train accuracy: 20.156000 val accuracy: 0.425000
# lr 3.900000e-07 reg 7.000000e+04 train accuracy: 20.271000 val accuracy: 0.425000
# lr 3.900000e-07 reg 9.000000e+04 train accuracy: 20.265000 val accuracy: 0.420000
# lr 3.900000e-07 reg 1.100000e+05 train accuracy: 20.138000 val accuracy: 0.409000
# lr 3.900000e-07 reg 1.300000e+05 train accuracy: 20.064000 val accuracy: 0.410000
# lr 3.900000e-07 reg 1.500000e+05 train accuracy: 19.890000 val accuracy: 0.408000
# lr 3.900000e-07 reg 1.700000e+05 train accuracy: 20.072000 val accuracy: 0.413000
# lr 3.900000e-07 reg 1.900000e+05 train accuracy: 19.895000 val accuracy: 0.411000
# lr 4.100000e-07 reg 1.000000e+04 train accuracy: 20.390000 val accuracy: 0.418000
# lr 4.100000e-07 reg 3.000000e+04 train accuracy: 20.345000 val accuracy: 0.424000
# lr 4.100000e-07 reg 5.000000e+04 train accuracy: 19.887000 val accuracy: 0.389000
# lr 4.100000e-07 reg 7.000000e+04 train accuracy: 20.111000 val accuracy: 0.403000
# lr 4.100000e-07 reg 9.000000e+04 train accuracy: 19.859000 val accuracy: 0.398000
# lr 4.100000e-07 reg 1.100000e+05 train accuracy: 19.861000 val accuracy: 0.406000
# lr 4.100000e-07 reg 1.300000e+05 train accuracy: 20.051000 val accuracy: 0.400000
# lr 4.100000e-07 reg 1.500000e+05 train accuracy: 19.537000 val accuracy: 0.393000
# lr 4.100000e-07 reg 1.700000e+05 train accuracy: 19.976000 val accuracy: 0.403000
# lr 4.100000e-07 reg 1.900000e+05 train accuracy: 19.459000 val accuracy: 0.390000
# lr 4.300000e-07 reg 1.000000e+04 train accuracy: 20.240000 val accuracy: 0.424000
# lr 4.300000e-07 reg 3.000000e+04 train accuracy: 20.110000 val accuracy: 0.406000
# lr 4.300000e-07 reg 5.000000e+04 train accuracy: 20.202000 val accuracy: 0.414000
# lr 4.300000e-07 reg 7.000000e+04 train accuracy: 19.909000 val accuracy: 0.405000
# lr 4.300000e-07 reg 9.000000e+04 train accuracy: 19.822000 val accuracy: 0.404000
# lr 4.300000e-07 reg 1.100000e+05 train accuracy: 19.994000 val accuracy: 0.406000
# lr 4.300000e-07 reg 1.300000e+05 train accuracy: 19.947000 val accuracy: 0.408000
# lr 4.300000e-07 reg 1.500000e+05 train accuracy: 19.689000 val accuracy: 0.402000
# lr 4.300000e-07 reg 1.700000e+05 train accuracy: 19.354000 val accuracy: 0.394000
# lr 4.300000e-07 reg 1.900000e+05 train accuracy: 19.278000 val accuracy: 0.387000
# lr 4.500000e-07 reg 1.000000e+04 train accuracy: 20.295000 val accuracy: 0.417000
# lr 4.500000e-07 reg 3.000000e+04 train accuracy: 20.298000 val accuracy: 0.423000
# lr 4.500000e-07 reg 5.000000e+04 train accuracy: 20.317000 val accuracy: 0.423000
# lr 4.500000e-07 reg 7.000000e+04 train accuracy: 19.997000 val accuracy: 0.406000
# lr 4.500000e-07 reg 9.000000e+04 train accuracy: 20.560000 val accuracy: 0.412000
# lr 4.500000e-07 reg 1.100000e+05 train accuracy: 19.911000 val accuracy: 0.411000
# lr 4.500000e-07 reg 1.300000e+05 train accuracy: 19.188000 val accuracy: 0.386000
# lr 4.500000e-07 reg 1.500000e+05 train accuracy: 20.000000 val accuracy: 0.392000
# lr 4.500000e-07 reg 1.700000e+05 train accuracy: 19.816000 val accuracy: 0.402000
# lr 4.500000e-07 reg 1.900000e+05 train accuracy: 19.636000 val accuracy: 0.378000
# lr 4.700000e-07 reg 1.000000e+04 train accuracy: 20.299000 val accuracy: 0.415000
# lr 4.700000e-07 reg 3.000000e+04 train accuracy: 20.212000 val accuracy: 0.417000
# lr 4.700000e-07 reg 5.000000e+04 train accuracy: 20.280000 val accuracy: 0.419000
# lr 4.700000e-07 reg 7.000000e+04 train accuracy: 20.402000 val accuracy: 0.426000
# lr 4.700000e-07 reg 9.000000e+04 train accuracy: 20.067000 val accuracy: 0.406000
# lr 4.700000e-07 reg 1.100000e+05 train accuracy: 19.809000 val accuracy: 0.378000
# lr 4.700000e-07 reg 1.300000e+05 train accuracy: 20.055000 val accuracy: 0.402000
# lr 4.700000e-07 reg 1.500000e+05 train accuracy: 20.006000 val accuracy: 0.413000
# lr 4.700000e-07 reg 1.700000e+05 train accuracy: 20.131000 val accuracy: 0.421000
# lr 4.700000e-07 reg 1.900000e+05 train accuracy: 19.016000 val accuracy: 0.399000
# lr 4.900000e-07 reg 1.000000e+04 train accuracy: 20.233000 val accuracy: 0.418000
# lr 4.900000e-07 reg 3.000000e+04 train accuracy: 20.283000 val accuracy: 0.413000
# lr 4.900000e-07 reg 5.000000e+04 train accuracy: 20.267000 val accuracy: 0.415000
# lr 4.900000e-07 reg 7.000000e+04 train accuracy: 20.521000 val accuracy: 0.428000
# lr 4.900000e-07 reg 9.000000e+04 train accuracy: 19.511000 val accuracy: 0.397000
# lr 4.900000e-07 reg 1.100000e+05 train accuracy: 19.621000 val accuracy: 0.400000
# lr 4.900000e-07 reg 1.300000e+05 train accuracy: 19.416000 val accuracy: 0.402000
# lr 4.900000e-07 reg 1.500000e+05 train accuracy: 20.142000 val accuracy: 0.406000
# lr 4.900000e-07 reg 1.700000e+05 train accuracy: 19.542000 val accuracy: 0.388000
# lr 4.900000e-07 reg 1.900000e+05 train accuracy: 19.910000 val accuracy: 0.400000
# best validation accuracy achieved: 0.433000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.406

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
# 在图像整体的边缘及梯度分布上比较相似。其次颜色分布也比较相似

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}
# net=TwoLayerNet(input_dim,hidden_dim,reg=0.001)
# print(net.params['b1'][:5])
# solver=Solver(net,data,update_rule='adam')
# solver.train()
learning_rate=np.arange(8e-5,9e-5,2e-6)
num_epochs=15
regularization_strengths = np.arange(1e-8,2e-7,3e-8)
best_net = None
best_acc=-1
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
for lr in learning_rate:
    for reg in regularization_strengths:
      model=TwoLayerNet(input_dim,hidden_dim,reg=reg)
      optim_config={'learning_rate':lr}
      solver=Solver(model,data,optim_config=optim_config,verbose=0,print_every=10,update_rule='adam',num_epochs=num_epochs)
      solver.train()
      print('hiddensize:{0} lr:{1} reg:{2} acac:{3}'.format(hidden_dim,lr,reg,solver.best_val_acc))
      if(solver.best_val_acc>best_acc):
        best_net=model
        best_acc=solver.best_val_acc
# pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# hiddensize:500 lr:8e-05 reg:1e-08 acac:0.556
# hiddensize:500 lr:8e-05 reg:4e-08 acac:0.562
# hiddensize:500 lr:8e-05 reg:7e-08 acac:0.554
# hiddensize:500 lr:8e-05 reg:1.0000000000000001e-07 acac:0.558
# hiddensize:500 lr:8e-05 reg:1.3000000000000003e-07 acac:0.563
# hiddensize:500 lr:8e-05 reg:1.6000000000000003e-07 acac:0.563
# hiddensize:500 lr:8e-05 reg:1.9000000000000003e-07 acac:0.563
# hiddensize:500 lr:8.2e-05 reg:1e-08 acac:0.562
# hiddensize:500 lr:8.2e-05 reg:4e-08 acac:0.571
# hiddensize:500 lr:8.2e-05 reg:7e-08 acac:0.559
# hiddensize:500 lr:8.2e-05 reg:1.0000000000000001e-07 acac:0.561
# hiddensize:500 lr:8.2e-05 reg:1.3000000000000003e-07 acac:0.565
# hiddensize:500 lr:8.2e-05 reg:1.6000000000000003e-07 acac:0.562
# hiddensize:500 lr:8.2e-05 reg:1.9000000000000003e-07 acac:0.563
# hiddensize:500 lr:8.4e-05 reg:1e-08 acac:0.563
# hiddensize:500 lr:8.4e-05 reg:4e-08 acac:0.561
# hiddensize:500 lr:8.4e-05 reg:7e-08 acac:0.566
# hiddensize:500 lr:8.4e-05 reg:1.0000000000000001e-07 acac:0.563
# hiddensize:500 lr:8.4e-05 reg:1.3000000000000003e-07 acac:0.563
# hiddensize:500 lr:8.4e-05 reg:1.6000000000000003e-07 acac:0.562
# hiddensize:500 lr:8.4e-05 reg:1.9000000000000003e-07 acac:0.575
# hiddensize:500 lr:8.599999999999999e-05 reg:1e-08 acac:0.572
# hiddensize:500 lr:8.599999999999999e-05 reg:4e-08 acac:0.565
# hiddensize:500 lr:8.599999999999999e-05 reg:7e-08 acac:0.565
# hiddensize:500 lr:8.599999999999999e-05 reg:1.0000000000000001e-07 acac:0.563
# hiddensize:500 lr:8.599999999999999e-05 reg:1.3000000000000003e-07 acac:0.552
# hiddensize:500 lr:8.599999999999999e-05 reg:1.6000000000000003e-07 acac:0.561
# hiddensize:500 lr:8.599999999999999e-05 reg:1.9000000000000003e-07 acac:0.565
# hiddensize:500 lr:8.799999999999998e-05 reg:1e-08 acac:0.578
# hiddensize:500 lr:8.799999999999998e-05 reg:4e-08 acac:0.565
# hiddensize:500 lr:8.799999999999998e-05 reg:7e-08 acac:0.572
# hiddensize:500 lr:8.799999999999998e-05 reg:1.0000000000000001e-07 acac:0.568
# hiddensize:500 lr:8.799999999999998e-05 reg:1.3000000000000003e-07 acac:0.561
# hiddensize:500 lr:8.799999999999998e-05 reg:1.6000000000000003e-07 acac:0.562
# hiddensize:500 lr:8.799999999999998e-05 reg:1.9000000000000003e-07 acac:0.573

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.558
